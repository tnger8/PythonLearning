# %%
#import Numpy
import numpy as np

# %%
arr = np.ones((5,5))

# %%
arr*10
# to create an array with ones but multiple by ten
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
# create an array with random numbers
np.random.seed(101)
# create the line with random numbers array
arr = np.random.randint(low=0,high=100,size=(5,5))

# %%
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
# find the largest in array
arr.max()
# Out:
# 95

# %%
# the smallest
arr.min()
# Out:
# 4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

# %%
pic = Image.open('C:/Users/TNGJ0/Downloads/flower.jpeg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=966x644 at 0x17569269668>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.asarray(pic)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape # shows the image array 3 refers to R G B
# Out:
# (644, 966, 3)

# %%
# show the image
plt.imshow(arr)

# %%
mycopy = arr.copy()

# %%
# R G B
mycopy[:,:,0] = 0 # take only red channel , zero the channel
mycopy[:,:,1] = 0 # take only green channel , zero the channel

# %%
plt.imshow(mycopy)  # the image has all Red and Green channel removed

# %% [markdown]
# Notice that these are the only blue channel left.
